# %%
import matplotlib.pyplot as plt

# 7465-3 [0.24192838 0.14022519 0.03211817 0.19346219 0.10622757 0.05508702 0.09254365]
# 7479-2 [0.20315169 0.07196343 0.00947703 0.07749893 0.03614061 0.01352371 0.04058474]
# 7479-0 [0.25265318 0.10053801 0.03749413 0.14339742 0.09111465 0.05582603 0.05597396]


# FOR coordinate x
data = [0.24, 0.20, 0.25]
boxes = ['', ' ', '  ']

fig, ax = plt.subplots(figsize=(6, 8))
ax.bar(boxes, data, color=['lightcoral', 'gold', 'lightgreen'])
ax.set_ylabel('')
ax.set_xlabel('')
ax.set_title('Artistic Vertical Histogram')

# Adding some artistic effects
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='y', which='major', labelsize=40)
# ax.tick_params(axis='both', which='minor', labelsize=8)

ax.spines["bottom"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

data = [0.14, 0.07, 0.10]
boxes = ['', '  ', '   ']

fig, ax = plt.subplots(figsize=(6, 8))
ax.bar(boxes, data, color=['lightcoral', 'gold', 'lightgreen'])
ax.set_ylabel('')
ax.set_xlabel('')
ax.set_title('Artistic Vertical Histogram')

# Adding some artistic effects
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=40)
# ax.tick_params(axis='both', which='minor', labelsize=8)

ax.spines["bottom"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)

plt.tight_layout()
plt.show()

# 0.32749245 0.13248594 0.09557531 0.26155189 0.14494197 0.13917358 0.08221006​
# ​
# [0.20315169 0.07196343 0.00947703 0.07749893 0.03614061 0.01352371 0.04058474]​
# ​
# [0.25265318 0.10053801 0.03749413 0.14339742 0.09111465 0.05582603 0.05597396]

# %%
import matplotlib.pyplot as plt

data = [0.03, 0.01, 0.04]
boxes = ['', '  ', '   ']

fig, ax = plt.subplots(figsize=(6, 8))
ax.bar(boxes, data, color=['lightcoral', 'gold', 'lightgreen'])
ax.set_ylabel('')
ax.set_xlabel('')
ax.set_title('Artistic Vertical Histogram')

# Adding some artistic effects
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
# ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=40)
# ax.tick_params(axis='both', which='minor', labelsize=8)

ax.spines["bottom"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)

plt.tight_layout()
plt.show()

# 0.32749245 0.13248594 0.09557531 0.26155189 0.14494197 0.13917358 0.08221006​
# ​
# [0.20315169 0.07196343 0.00947703 0.07749893 0.03614061 0.01352371 0.04058474]​
# ​
# [0.25265318 0.10053801 0.03749413 0.14339742 0.09111465 0.05582603 0.05597396]

# %%
import matplotlib.pyplot as plt

data = [0.19, 0.08, 0.14]
boxes = ['', '  ', '   ']

fig, ax = plt.subplots(figsize=(6, 8))
ax.bar(boxes, data, color=['lightcoral', 'gold', 'lightgreen'])
ax.set_ylabel('')
ax.set_xlabel('')
ax.set_title('Artistic Vertical Histogram')

# Adding some artistic effects
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=40)
# ax.tick_params(axis='both', which='minor', labelsize=8)

ax.spines["bottom"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)

plt.tight_layout()
plt.show()

# 0.32749245 0.13248594 0.09557531 0.26155189 0.14494197 0.13917358 0.08221006​
# ​
# [0.20315169 0.07196343 0.00947703 0.07749893 0.03614061 0.01352371 0.04058474]​
# ​
# [0.25265318 0.10053801 0.03749413 0.14339742 0.09111465 0.05582603 0.05597396]

# %%
import matplotlib.pyplot as plt

data = [0.11, 0.04, 0.09]
boxes = ['', '  ', '   ']

fig, ax = plt.subplots(figsize=(6, 8))
ax.bar(boxes, data, color=['lightcoral', 'gold', 'lightgreen'])
ax.set_ylabel('')
ax.set_xlabel('')
ax.set_title('Artistic Vertical Histogram')

# Adding some artistic effects
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=40)
# ax.tick_params(axis='both', which='minor', labelsize=8)

ax.spines["bottom"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)

plt.tight_layout()
plt.show()

# 0.32749245 0.13248594 0.09557531 0.26155189 0.14494197 0.13917358 0.08221006​
# ​
# [0.20315169 0.07196343 0.00947703 0.07749893 0.03614061 0.01352371 0.04058474]​
# ​
# [0.25265318 0.10053801 0.03749413 0.14339742 0.09111465 0.05582603 0.05597396]

# %%
import matplotlib.pyplot as plt

data = [0.06, 0.01, 0.06]
boxes = ['', '  ', '   ']

fig, ax = plt.subplots(figsize=(6, 8))
ax.bar(boxes, data, color=['lightcoral', 'gold', 'lightgreen'])
ax.set_ylabel('')
ax.set_xlabel('')
ax.set_title('Artistic Vertical Histogram')

# Adding some artistic effects
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=40)
# ax.tick_params(axis='both', which='minor', labelsize=8)

ax.spines["bottom"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)

plt.tight_layout()
plt.show()

# 0.32749245 0.13248594 0.09557531 0.26155189 0.14494197 0.13917358 0.08221006​
# ​
# [0.20315169 0.07196343 0.00947703 0.07749893 0.03614061 0.01352371 0.04058474]​
# ​
# [0.25265318 0.10053801 0.03749413 0.14339742 0.09111465 0.05582603 0.05597396]

# %%
import matplotlib.pyplot as plt

data = [0.09, 0.04, 0.06]
boxes = ['', '  ', '   ']

fig, ax = plt.subplots(figsize=(6, 8))
ax.bar(boxes, data, color=['lightcoral', 'gold', 'lightgreen'])
ax.set_ylabel('')
ax.set_xlabel('')
ax.set_title('Artistic Vertical Histogram')

# Adding some artistic effects
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.xaxis.tick_bottom()
ax.yaxis.tick_left()
ax.tick_params(axis='both', which='major', labelsize=40)
# ax.tick_params(axis='both', which='minor', labelsize=8)

ax.spines["bottom"].set_linewidth(3)
ax.spines["left"].set_linewidth(3)

plt.tight_layout()
plt.show()

# 0.32749245 0.13248594 0.09557531 0.26155189 0.14494197 0.13917358 0.08221006​
# ​
# [0.20315169 0.07196343 0.00947703 0.07749893 0.03614061 0.01352371 0.04058474]​
# ​
# [0.25265318 0.10053801 0.03749413 0.14339742 0.09111465 0.05582603 0.05597396]
